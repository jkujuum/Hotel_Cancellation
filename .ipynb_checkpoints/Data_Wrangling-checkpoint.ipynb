# %% [markdown]
# # Data Wrangling for Hotel demand

# %%
#load python packages
import os
import pandas as pd
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
#from pandas_profiling import ProfileReport
# %matplotlib inline

# %%
pwd
# Out:
# 'D:\\Jupyter_Notebook\\Hotel_Cancellation'

# %%
ls
# Out:
#  Volume in drive D is New Volume
#  Volume Serial Number is 9CD5-20C5
#
#  Directory of D:\Jupyter_Notebook\Hotel_Cancellation
#
# 07/07/2020  04:47 PM    <DIR>          .
# 07/07/2020  04:47 PM    <DIR>          ..
# 07/07/2020  04:46 PM    <DIR>          .ipynb_checkpoints
# 07/07/2020  04:47 PM    <DIR>          data
# 07/06/2020  11:07 PM           476,458 Data_Wrangling.ipynb
# 07/07/2020  04:44 PM         3,161,800 Exploratory Data Analysis.ipynb
# 07/07/2020  10:49 AM            35,635 Feature Engineering.ipynb
# 07/06/2020  02:58 PM    <DIR>          figs
# 06/27/2020  09:57 PM        18,690,371 hotel_data_report.html
# 07/07/2020  10:58 AM    <DIR>          Modeling
# 06/27/2020  09:57 PM                14 README.md
#                5 File(s)     22,364,278 bytes
#                6 Dir(s)  68,524,556,288 bytes free

# %% [markdown]
# ### Load the data

# %%
hotel = pd.read_csv('D:\Jupyter_Notebook\Hotel_Cancellation\data\hotel_bookings.csv')

# %%
hotel.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# 1                        0                     0       2  ...    No Deposit
# 2                        0                     1       1  ...    No Deposit
# 3                        0                     1       1  ...    No Deposit
# 4                        0                     2       2  ...    No Deposit
#
#    agent company days_in_waiting_list customer_type   adr  \
# 0    NaN     NaN                    0     Transient   0.0
# 1    NaN     NaN                    0     Transient   0.0
# 2    NaN     NaN                    0     Transient  75.0
# 3  304.0     NaN                    0     Transient  75.0
# 4  240.0     NaN                    0     Transient  98.0
#
#    required_car_parking_spaces  total_of_special_requests  reservation_status  \
# 0                            0                          0           Check-Out
# 1                            0                          0           Check-Out
# 2                            0                          0           Check-Out
# 3                            0                          0           Check-Out
# 4                            0                          1           Check-Out
#
#   reservation_status_date
# 0              2015-07-01
# 1              2015-07-01
# 2              2015-07-02
# 3              2015-07-02
# 4              2015-07-03
#
# [5 rows x 32 columns]

# %% [markdown]
# ### Data Definition

# %%
hotel.shape
# Out:
# (119390, 32)

# %%
hotel.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %% [markdown]
# The definition of each column is as following:
#
# - `hotelHotel` (H1 = Resort Hotel or H2 = City Hotel)
# - `is_canceledValue` indicating if the booking was canceled (1) or not (0)
# - `lead_time` Number of days that elapsed between the entering date of the booking into the PMS and the arrival date
# - `arrival_date_year` Year of arrival date
# - `arrival_date_month` Month of arrival date
# - `arrival_date_week_number` Week number of year for arrival date
# - `arrival_date_day_of_month` Day of arrival date
# - `stays_in_weekend_nights` Number of weekend nights (Saturday or Sunday) the guest stayed or booked to stay at the hotel
# - `stays_in_week_nights` Number of week nights (Monday to Friday) the guest stayed or booked to stay at the hotel
# - `adults` Number of adults
# - `children` Number of children
# - `babies` Number of babies
# - `meal` Type of meal booked. Categories are presented in standard hospitality meal packages:
#     - Undefined/SC – no meal package;
#     - BB – Bed & Breakfast;
#     - HB – Half board (breakfast and one other meal – usually dinner);
#     - FB – Full board (breakfast, lunch and dinner)
# - `country` Country of origin. Categories are represented in the ISO 3155–3:2013 format
# - `market_segment` Market segment designation. In categories, the term “TA” means “Travel Agents” and “TO” means “Tour Operators”
# - `distribution_channel` Booking distribution channel. The term “TA” means “Travel Agents” and “TO” means “Tour Operators”
# - `is_repeated_guest` Value indicating if the booking name was from a repeated guest (1) or not (0)
# - `previous_cancellations` Number of previous bookings that were cancelled by the customer prior to the current booking
# - `previous_bookings_not_canceled` Number of previous bookings not cancelled by the customer prior to the current booking
# - `reserved_room_type` Code of room type reserved. Code is presented instead of designation for anonymity reasons.
# - `assigned_room_type` Code for the type of room assigned to the booking. Sometimes the assigned room type differs from the reserved room type due to hotel operation reasons (e.g. overbooking) or by customer request. Code is presented instead of designation for anonymity reasons.
# - `booking_changes` Number of changes/amendments made to the booking from the moment the booking was entered on the PMS until the moment of check-in or cancellation
# - `deposit_type` Indication on if the customer made a deposit to guarantee the booking. This variable can assume three categories:
#     - No Deposit – no deposit was made;
#     - Non Refund – a deposit was made in the value of the total stay cost;
#     - Refundable – a deposit was made with a value under the total cost of stay.
# - `agent` ID of the travel agency that made the booking
# - `company` ID of the company/entity that made the booking or responsible for paying the booking. ID is presented instead of designation for anonymity reasons
# - `days_in_waiting_list` Number of days the booking was in the waiting list before it was confirmed to the customer
# - `customer_type` Type of booking, assuming one of four categories:
#     - Contract - when the booking has an allotment or other type of contract associated to it;
#     - Group – when the booking is associated to a group;
#     - Transient – when the booking is not part of a group or contract, and is not associated to other transient booking;
#     - Transient-party – when the booking is transient, but is associated to at least other transient booking
# - `adr` Average Daily Rate as defined by dividing the sum of all lodging transactions by the total number of staying nights
# - `required_car_parking_spaces` Number of car parking spaces required by the customer
# - `total_of_special_requests` Number of special requests made by the customer (e.g. twin bed or high floor)
# - `reservation_status` Reservation last status, assuming one of three categories: Canceled – booking was canceled by the customer; Check-Out – customer has checked in but already departed; No-Show – customer did not check-in and did inform the hotel of the reason why
# - `reservation_status_date` Date at which the last status was set. This variable can be used in conjunction with the ReservationStatus to understand when was the booking canceled or when did the customer checked-out of the hotel

# %%
# form a pandas data profiling report to have a rough understanding of each column
#profile = ProfileReport(hotel, title='Hotel Profiling Report', html={'style':{'full_width':True}})

# %%
#profile.to_widgets()

# %%
# save it into a html file "hotel_data_report.html"
#profile.to_file(output_file="hotel_data_report.html")

# %% [markdown]
# ### Look for duplicate rows

# %%
duplicateRowsDF = hotel[hotel.duplicated()]
duplicateRowsDF
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 5       Resort Hotel            0         14               2015
# 22      Resort Hotel            0         72               2015
# 43      Resort Hotel            0         70               2015
# 138     Resort Hotel            1          5               2015
# 200     Resort Hotel            0          0               2015
# ...              ...          ...        ...                ...
# 119349    City Hotel            0        186               2017
# 119352    City Hotel            0         63               2017
# 119353    City Hotel            0         63               2017
# 119354    City Hotel            0         63               2017
# 119373    City Hotel            0        175               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 5                    July                        27
# 22                   July                        27
# 43                   July                        27
# 138                  July                        28
# 200                  July                        28
# ...                   ...                       ...
# 119349             August                        35
# 119352             August                        35
# 119353             August                        35
# 119354             August                        35
# 119373             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 5                               1                        0
# 22                              1                        2
# 43                              2                        2
# 138                             5                        1
# 200                             7                        0
# ...                           ...                      ...
# 119349                         31                        0
# 119352                         31                        0
# 119353                         31                        0
# 119354                         31                        0
# 119373                         31                        1
#
#         stays_in_week_nights  adults  ...  deposit_type  agent company  \
# 5                          2       2  ...    No Deposit  240.0     NaN
# 22                         4       2  ...    No Deposit  250.0     NaN
# 43                         3       2  ...    No Deposit  250.0     NaN
# 138                        0       2  ...    No Deposit  240.0     NaN
# 200                        1       1  ...    No Deposit  240.0     NaN
# ...                      ...     ...  ...           ...    ...     ...
# 119349                     3       2  ...    No Deposit    9.0     NaN
# 119352                     3       3  ...    No Deposit    9.0     NaN
# 119353                     3       3  ...    No Deposit    9.0     NaN
# 119354                     3       3  ...    No Deposit    9.0     NaN
# 119373                     3       1  ...    No Deposit   42.0     NaN
#
#        days_in_waiting_list    customer_type     adr  \
# 5                         0        Transient   98.00
# 22                        0        Transient   84.67
# 43                        0        Transient  137.00
# 138                       0        Transient   97.00
# 200                       0        Transient  109.80
# ...                     ...              ...     ...
# 119349                    0        Transient  126.00
# 119352                    0  Transient-Party  195.33
# 119353                    0  Transient-Party  195.33
# 119354                    0  Transient-Party  195.33
# 119373                    0        Transient   82.35
#
#         required_car_parking_spaces  total_of_special_requests  \
# 5                                 0                          1
# 22                                0                          1
# 43                                0                          1
# 138                               0                          0
# 200                               0                          3
# ...                             ...                        ...
# 119349                            0                          2
# 119352                            0                          2
# 119353                            0                          2
# 119354                            0                          2
# 119373                            0                          1
#
#         reservation_status reservation_status_date
# 5                Check-Out              2015-07-03
# 22               Check-Out              2015-07-07
# 43               Check-Out              2015-07-07
# 138               Canceled              2015-07-01
# 200              Check-Out              2015-07-08
# ...                    ...                     ...
# 119349           Check-Out              2017-09-03
# 119352           Check-Out              2017-09-03
# 119353           Check-Out              2017-09-03
# 119354           Check-Out              2017-09-03
# 119373           Check-Out              2017-09-04
#
# [31994 rows x 32 columns]

# %%
duplicateRowsDF.customer_type.value_counts()
# Out:
# Transient          17627
# Transient-Party    13397
# Contract             937
# Group                 33
# Name: customer_type, dtype: int64

# %%
duplicateRowsDF.children.value_counts()
# Out:
# 0.0    31768
# 1.0      166
# 2.0       59
# 3.0        1
# Name: children, dtype: int64

# %%
duplicateRowsDF.previous_cancellations.value_counts()
# Out:
# 0     27195
# 1      4644
# 24       46
# 26       25
# 25       23
# 19       18
# 14       13
# 13        8
# 11        8
# 6         5
# 3         4
# 2         4
# 4         1
# Name: previous_cancellations, dtype: int64

# %%
duplicateRowsDF.stays_in_weekend_nights.value_counts()
# Out:
# 0    16847
# 1     7969
# 2     6894
# 4      121
# 3      109
# 6       40
# 5        9
# 7        4
# 9        1
# Name: stays_in_weekend_nights, dtype: int64

# %%
duplicateRowsDF.adults.value_counts()
# Out:
# 2    25183
# 1     6524
# 3      267
# 0       18
# 4        2
# Name: adults, dtype: int64

# %% [markdown]
# The duplicated rows in the dataframe may not be useless information. It could be some identical custmers or a group of customers making very similiar orders.It is not wise to just drop all the duplicated rows. In this project, I will keep all these rows.

# %% [markdown]
# ### Remove incorrect rows

# %%
hotel.describe().T
# Out:
#                                    count         mean         std      min  \
# is_canceled                     119390.0     0.370416    0.482918     0.00
# lead_time                       119390.0   104.011416  106.863097     0.00
# arrival_date_year               119390.0  2016.156554    0.707476  2015.00
# arrival_date_week_number        119390.0    27.165173   13.605138     1.00
# arrival_date_day_of_month       119390.0    15.798241    8.780829     1.00
# stays_in_weekend_nights         119390.0     0.927599    0.998613     0.00
# stays_in_week_nights            119390.0     2.500302    1.908286     0.00
# adults                          119390.0     1.856403    0.579261     0.00
# children                        119386.0     0.103890    0.398561     0.00
# babies                          119390.0     0.007949    0.097436     0.00
# is_repeated_guest               119390.0     0.031912    0.175767     0.00
# previous_cancellations          119390.0     0.087118    0.844336     0.00
# previous_bookings_not_canceled  119390.0     0.137097    1.497437     0.00
# booking_changes                 119390.0     0.221124    0.652306     0.00
# agent                           103050.0    86.693382  110.774548     1.00
# company                           6797.0   189.266735  131.655015     6.00
# days_in_waiting_list            119390.0     2.321149   17.594721     0.00
# adr                             119390.0   101.831122   50.535790    -6.38
# required_car_parking_spaces     119390.0     0.062518    0.245291     0.00
# total_of_special_requests       119390.0     0.571363    0.792798     0.00
#
#                                     25%       50%     75%     max
# is_canceled                        0.00     0.000     1.0     1.0
# lead_time                         18.00    69.000   160.0   737.0
# arrival_date_year               2016.00  2016.000  2017.0  2017.0
# arrival_date_week_number          16.00    28.000    38.0    53.0
# arrival_date_day_of_month          8.00    16.000    23.0    31.0
# stays_in_weekend_nights            0.00     1.000     2.0    19.0
# stays_in_week_nights               1.00     2.000     3.0    50.0
# adults                             2.00     2.000     2.0    55.0
# children                           0.00     0.000     0.0    10.0
# babies                             0.00     0.000     0.0    10.0
# is_repeated_guest                  0.00     0.000     0.0     1.0
# previous_cancellations             0.00     0.000     0.0    26.0
# previous_bookings_not_canceled     0.00     0.000     0.0    72.0
# booking_changes                    0.00     0.000     0.0    21.0
# agent                              9.00    14.000   229.0   535.0
# company                           62.00   179.000   270.0   543.0
# days_in_waiting_list               0.00     0.000     0.0   391.0
# adr                               69.29    94.575   126.0  5400.0
# required_car_parking_spaces        0.00     0.000     0.0     8.0
# total_of_special_requests          0.00     0.000     1.0     5.0

# %% [markdown]
# Check adult column. Min number for adult columns is 0. There must be some one making the reservation, otherwise, it could be an error.

# %%
hotel.adults.value_counts()
# Out:
# 2     89680
# 1     23027
# 3      6202
# 0       403
# 4        62
# 26        5
# 27        2
# 20        2
# 5         2
# 55        1
# 50        1
# 40        1
# 10        1
# 6         1
# Name: adults, dtype: int64

# %%
hotel[hotel.adults == 50]
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 1643  Resort Hotel            1        336               2015
#
#      arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 1643          September                        37                          7
#
#       stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 1643                        1                     2      50  ...
#
#       deposit_type  agent company days_in_waiting_list customer_type  adr  \
# 1643    No Deposit    NaN     NaN                    0         Group  0.0
#
#       required_car_parking_spaces  total_of_special_requests  \
# 1643                            0                          0
#
#       reservation_status reservation_status_date
# 1643            Canceled              2015-01-18
#
# [1 rows x 32 columns]

# %%
hotel[hotel.adults == 55]
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 2173  Resort Hotel            1        338               2015
#
#      arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 2173            October                        41                          4
#
#       stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 2173                        2                     0      55  ...
#
#       deposit_type  agent company days_in_waiting_list customer_type  adr  \
# 2173    No Deposit    NaN     NaN                    0         Group  0.0
#
#       required_car_parking_spaces  total_of_special_requests  \
# 2173                            0                          0
#
#       reservation_status reservation_status_date
# 2173            Canceled              2015-01-02
#
# [1 rows x 32 columns]

# %%
hotel[hotel.adults == 27]
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 1917  Resort Hotel            1        349               2015
# 1962  Resort Hotel            1        352               2015
#
#      arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 1917          September                        39                         21
# 1962          September                        39                         24
#
#       stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 1917                        1                     3      27  ...
# 1962                        1                     3      27  ...
#
#       deposit_type  agent company days_in_waiting_list customer_type  adr  \
# 1917    No Deposit    NaN     NaN                    0         Group  0.0
# 1962    No Deposit    NaN     NaN                    0         Group  0.0
#
#       required_car_parking_spaces  total_of_special_requests  \
# 1917                            0                          0
# 1962                            0                          0
#
#       reservation_status reservation_status_date
# 1917            Canceled              2015-01-02
# 1962            Canceled              2015-01-02
#
# [2 rows x 32 columns]

# %%
hotel[hotel.adults == 26]
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 1587  Resort Hotel            1        333               2015
# 1752  Resort Hotel            1        340               2015
# 1884  Resort Hotel            1        347               2015
# 2003  Resort Hotel            1        354               2015
# 2164  Resort Hotel            1        361               2015
#
#      arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 1587          September                        36                          5
# 1752          September                        37                         12
# 1884          September                        38                         19
# 2003          September                        39                         26
# 2164            October                        40                          3
#
#       stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 1587                        2                     5      26  ...
# 1752                        2                     5      26  ...
# 1884                        2                     5      26  ...
# 2003                        2                     5      26  ...
# 2164                        2                     5      26  ...
#
#       deposit_type  agent company days_in_waiting_list customer_type  adr  \
# 1587    No Deposit   96.0     NaN                    0         Group  0.0
# 1752    No Deposit   96.0     NaN                    0         Group  0.0
# 1884    No Deposit   96.0     NaN                    0         Group  0.0
# 2003    No Deposit   96.0     NaN                    0         Group  0.0
# 2164    No Deposit   96.0     NaN                    0         Group  0.0
#
#       required_car_parking_spaces  total_of_special_requests  \
# 1587                            0                          0
# 1752                            0                          0
# 1884                            0                          0
# 2003                            0                          0
# 2164                            0                          0
#
#       reservation_status reservation_status_date
# 1587            Canceled              2015-01-02
# 1752            Canceled              2015-01-02
# 1884            Canceled              2015-01-02
# 2003            Canceled              2015-01-02
# 2164            Canceled              2015-01-02
#
# [5 rows x 32 columns]

# %%
hotel[hotel.adults == 20]
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 2228  Resort Hotel            1        328               2015
# 2418  Resort Hotel            1        334               2015
#
#      arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 2228            October                        41                          6
# 2418            October                        42                         12
#
#       stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 2228                        2                     5      20  ...
# 2418                        2                     5      20  ...
#
#       deposit_type  agent company days_in_waiting_list customer_type  adr  \
# 2228    No Deposit    NaN     NaN                    0         Group  0.0
# 2418    No Deposit    NaN     NaN                    0         Group  0.0
#
#       required_car_parking_spaces  total_of_special_requests  \
# 2228                            0                          0
# 2418                            0                          0
#
#       reservation_status reservation_status_date
# 2228            Canceled              2015-09-03
# 2418            Canceled              2015-01-02
#
# [2 rows x 32 columns]

# %%
hotel[hotel.adults == 40]
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 1539  Resort Hotel            1        304               2015
#
#      arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 1539          September                        36                          3
#
#       stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 1539                        0                     3      40  ...
#
#       deposit_type  agent company days_in_waiting_list customer_type  adr  \
# 1539    No Deposit    NaN     NaN                    0         Group  0.0
#
#       required_car_parking_spaces  total_of_special_requests  \
# 1539                            0                          0
#
#       reservation_status reservation_status_date
# 1539            Canceled              2015-01-02
#
# [1 rows x 32 columns]

# %%
hotel[hotel.adults == 10]
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 2417  Resort Hotel            1        334               2015
#
#      arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 2417            October                        42                         12
#
#       stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 2417                        2                     5      10  ...
#
#       deposit_type  agent company days_in_waiting_list customer_type  adr  \
# 2417    No Deposit    NaN     NaN                    0         Group  0.0
#
#       required_car_parking_spaces  total_of_special_requests  \
# 2417                            0                          0
#
#       reservation_status reservation_status_date
# 2417            Canceled              2015-01-02
#
# [1 rows x 32 columns]

# %%
hotel[hotel.adults == 5]
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 2231  Resort Hotel            1        328               2015
# 2419  Resort Hotel            1        334               2015
#
#      arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 2231            October                        41                          6
# 2419            October                        42                         12
#
#       stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 2231                        2                     5       5  ...
# 2419                        2                     5       5  ...
#
#       deposit_type  agent company days_in_waiting_list customer_type  adr  \
# 2231    No Deposit    NaN     NaN                    0         Group  0.0
# 2419    No Deposit    NaN     NaN                    0         Group  0.0
#
#       required_car_parking_spaces  total_of_special_requests  \
# 2231                            0                          0
# 2419                            0                          0
#
#       reservation_status reservation_status_date
# 2231            Canceled              2015-01-02
# 2419            Canceled              2015-01-02
#
# [2 rows x 32 columns]

# %%
hotel[hotel.adults == 6]
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 2229  Resort Hotel            1        328               2015
#
#      arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 2229            October                        41                          6
#
#       stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 2229                        2                     5       6  ...
#
#       deposit_type  agent company days_in_waiting_list customer_type  adr  \
# 2229    No Deposit    NaN     NaN                    0         Group  0.0
#
#       required_car_parking_spaces  total_of_special_requests  \
# 2229                            0                          0
#
#       reservation_status reservation_status_date
# 2229            Canceled              2015-01-02
#
# [1 rows x 32 columns]

# %%
hotel[hotel.adults == 4]
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 125     Resort Hotel            0         32               2015
# 354     Resort Hotel            0          0               2015
# 1023    Resort Hotel            1         95               2015
# 6116    Resort Hotel            1         26               2016
# 7966    Resort Hotel            0        320               2016
# ...              ...          ...        ...                ...
# 114656    City Hotel            0        112               2017
# 116395    City Hotel            0         84               2017
# 117921    City Hotel            0         14               2017
# 118480    City Hotel            0        174               2017
# 118911    City Hotel            0        137               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 125                  July                        27
# 354                  July                        29
# 1023               August                        33
# 6116                  May                        22
# 7966            September                        37
# ...                   ...                       ...
# 114656               June                        25
# 116395               July                        29
# 117921             August                        32
# 118480             August                        33
# 118911             August                        34
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 125                             4                        0
# 354                            13                        1
# 1023                           10                        2
# 6116                           26                        0
# 7966                            5                        1
# ...                           ...                      ...
# 114656                         21                        0
# 116395                         16                        2
# 117921                          9                        0
# 118480                         19                        1
# 118911                         23                        0
#
#         stays_in_week_nights  adults  ...  deposit_type  agent company  \
# 125                        1       4  ...    No Deposit    NaN     NaN
# 354                        1       4  ...    No Deposit    NaN     NaN
# 1023                       5       4  ...    No Deposit    NaN     NaN
# 6116                       3       4  ...    No Deposit  250.0     NaN
# 7966                       2       4  ...    No Deposit  250.0     NaN
# ...                      ...     ...  ...           ...    ...     ...
# 114656                     4       4  ...    No Deposit    9.0     NaN
# 116395                     1       4  ...    No Deposit    9.0     NaN
# 117921                     3       4  ...    No Deposit  159.0     NaN
# 118480                     1       4  ...    No Deposit   79.0     NaN
# 118911                     4       4  ...    No Deposit    7.0     NaN
#
#        days_in_waiting_list customer_type     adr  \
# 125                       0     Transient    0.00
# 354                       0     Transient  150.00
# 1023                      0     Transient  190.00
# 6116                      0     Transient  175.00
# 7966                      0     Transient  161.75
# ...                     ...           ...     ...
# 114656                    0     Transient  233.00
# 116395                    0     Transient  234.00
# 117921                    0     Transient  275.90
# 118480                    0     Transient  171.60
# 118911                    0     Transient  225.48
#
#         required_car_parking_spaces  total_of_special_requests  \
# 125                               0                          1
# 354                               0                          0
# 1023                              0                          0
# 6116                              0                          0
# 7966                              0                          0
# ...                             ...                        ...
# 114656                            0                          2
# 116395                            0                          3
# 117921                            0                          0
# 118480                            0                          0
# 118911                            0                          2
#
#         reservation_status reservation_status_date
# 125              Check-Out              2015-07-05
# 354              Check-Out              2015-07-15
# 1023              Canceled              2015-06-26
# 6116              Canceled              2016-05-23
# 7966             Check-Out              2016-09-08
# ...                    ...                     ...
# 114656           Check-Out              2017-06-25
# 116395           Check-Out              2017-07-19
# 117921           Check-Out              2017-08-12
# 118480           Check-Out              2017-08-21
# 118911           Check-Out              2017-08-27
#
# [62 rows x 32 columns]

# %% [markdown]
# It is interesting that all orders made with more than 4 people groups all get cancelled.These orders are all made to the Resort Hotel. This could either be orders made by mistake, or the hotel did something not to satisfying with group orders.

# %%
#There are 403 rows that the adults number is 0. 
adult_0 = hotel[hotel.adults == 0]
adult_0
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 2224    Resort Hotel            0          1               2015
# 2409    Resort Hotel            0          0               2015
# 3181    Resort Hotel            0         36               2015
# 3684    Resort Hotel            0        165               2015
# 3708    Resort Hotel            0        165               2015
# ...              ...          ...        ...                ...
# 117204    City Hotel            0        296               2017
# 117274    City Hotel            0        276               2017
# 117303    City Hotel            0        291               2017
# 117453    City Hotel            0        159               2017
# 118200    City Hotel            0         10               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 2224              October                        41
# 2409              October                        42
# 3181             November                        47
# 3684             December                        53
# 3708             December                        53
# ...                   ...                       ...
# 117204               July                        30
# 117274               July                        31
# 117303               July                        30
# 117453               July                        31
# 118200             August                        32
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 2224                            6                        0
# 2409                           12                        0
# 3181                           20                        1
# 3684                           30                        1
# 3708                           30                        2
# ...                           ...                      ...
# 117204                         27                        1
# 117274                         30                        2
# 117303                         29                        2
# 117453                         31                        1
# 118200                         12                        2
#
#         stays_in_week_nights  adults  ...  deposit_type  agent company  \
# 2224                       3       0  ...    No Deposit    NaN   174.0
# 2409                       0       0  ...    No Deposit    NaN   174.0
# 3181                       2       0  ...    No Deposit   38.0     NaN
# 3684                       4       0  ...    No Deposit  308.0     NaN
# 3708                       4       0  ...    No Deposit  308.0     NaN
# ...                      ...     ...  ...           ...    ...     ...
# 117204                     3       0  ...    No Deposit    9.0     NaN
# 117274                     1       0  ...    No Deposit    9.0     NaN
# 117303                     2       0  ...    No Deposit    9.0     NaN
# 117453                     3       0  ...    No Deposit    9.0     NaN
# 118200                     2       0  ...    No Deposit    NaN     NaN
#
#        days_in_waiting_list    customer_type     adr  \
# 2224                      0  Transient-Party    0.00
# 2409                      0        Transient    0.00
# 3181                      0  Transient-Party    0.00
# 3684                    122  Transient-Party    0.00
# 3708                    122  Transient-Party    0.00
# ...                     ...              ...     ...
# 117204                    0        Transient   98.85
# 117274                    0        Transient   93.64
# 117303                    0        Transient   98.85
# 117453                    0        Transient  121.88
# 118200                    0  Transient-Party    6.00
#
#         required_car_parking_spaces  total_of_special_requests  \
# 2224                              0                          0
# 2409                              0                          0
# 3181                              0                          0
# 3684                              0                          0
# 3708                              0                          0
# ...                             ...                        ...
# 117204                            0                          1
# 117274                            0                          2
# 117303                            0                          1
# 117453                            0                          1
# 118200                            0                          1
#
#         reservation_status reservation_status_date
# 2224             Check-Out              2015-10-06
# 2409             Check-Out              2015-10-12
# 3181             Check-Out              2015-11-23
# 3684             Check-Out              2016-01-04
# 3708             Check-Out              2016-01-05
# ...                    ...                     ...
# 117204           Check-Out              2017-07-31
# 117274           Check-Out              2017-08-02
# 117303           Check-Out              2017-08-02
# 117453           Check-Out              2017-08-04
# 118200           Check-Out              2017-08-16
#
# [403 rows x 32 columns]

# %%
# Check children numbers
adult_0.children.value_counts()
# Out:
# 2.0    208
# 0.0    180
# 3.0     11
# 1.0      4
# Name: children, dtype: int64

# %% [markdown]
# The hotel reservations that with 0 adult, means these rooms are booked by people under 18(21) years old. However, there are 180 orders that made by 0 adult and 0 childrens. These rows need to be dropped.

# %%
hotel[(hotel.adults == 0) & (hotel.children ==0)]
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 2224    Resort Hotel            0          1               2015
# 2409    Resort Hotel            0          0               2015
# 3181    Resort Hotel            0         36               2015
# 3684    Resort Hotel            0        165               2015
# 3708    Resort Hotel            0        165               2015
# ...              ...          ...        ...                ...
# 115029    City Hotel            0        107               2017
# 115091    City Hotel            0          1               2017
# 116251    City Hotel            0         44               2017
# 116534    City Hotel            0          2               2017
# 117087    City Hotel            0        170               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 2224              October                        41
# 2409              October                        42
# 3181             November                        47
# 3684             December                        53
# 3708             December                        53
# ...                   ...                       ...
# 115029               June                        26
# 115091               June                        26
# 116251               July                        28
# 116534               July                        28
# 117087               July                        30
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 2224                            6                        0
# 2409                           12                        0
# 3181                           20                        1
# 3684                           30                        1
# 3708                           30                        2
# ...                           ...                      ...
# 115029                         27                        0
# 115091                         30                        0
# 116251                         15                        1
# 116534                         15                        2
# 117087                         27                        0
#
#         stays_in_week_nights  adults  ...  deposit_type  agent company  \
# 2224                       3       0  ...    No Deposit    NaN   174.0
# 2409                       0       0  ...    No Deposit    NaN   174.0
# 3181                       2       0  ...    No Deposit   38.0     NaN
# 3684                       4       0  ...    No Deposit  308.0     NaN
# 3708                       4       0  ...    No Deposit  308.0     NaN
# ...                      ...     ...  ...           ...    ...     ...
# 115029                     3       0  ...    No Deposit    7.0     NaN
# 115091                     1       0  ...    No Deposit    NaN     NaN
# 116251                     1       0  ...    No Deposit  425.0     NaN
# 116534                     5       0  ...    No Deposit    9.0     NaN
# 117087                     2       0  ...    No Deposit   52.0     NaN
#
#        days_in_waiting_list    customer_type     adr  \
# 2224                      0  Transient-Party    0.00
# 2409                      0        Transient    0.00
# 3181                      0  Transient-Party    0.00
# 3684                    122  Transient-Party    0.00
# 3708                    122  Transient-Party    0.00
# ...                     ...              ...     ...
# 115029                    0        Transient  100.80
# 115091                    0        Transient    0.00
# 116251                    0        Transient   73.80
# 116534                    0  Transient-Party   22.86
# 117087                    0        Transient    0.00
#
#         required_car_parking_spaces  total_of_special_requests  \
# 2224                              0                          0
# 2409                              0                          0
# 3181                              0                          0
# 3684                              0                          0
# 3708                              0                          0
# ...                             ...                        ...
# 115029                            0                          0
# 115091                            1                          1
# 116251                            0                          0
# 116534                            0                          1
# 117087                            0                          0
#
#         reservation_status reservation_status_date
# 2224             Check-Out              2015-10-06
# 2409             Check-Out              2015-10-12
# 3181             Check-Out              2015-11-23
# 3684             Check-Out              2016-01-04
# 3708             Check-Out              2016-01-05
# ...                    ...                     ...
# 115029           Check-Out              2017-06-30
# 115091           Check-Out              2017-07-01
# 116251           Check-Out              2017-07-17
# 116534           Check-Out              2017-07-22
# 117087           Check-Out              2017-07-29
#
# [180 rows x 32 columns]

# %%
no_a_c = hotel[(hotel.adults == 0) & (hotel.children ==0)].index.tolist()

# %%
hotel = hotel.drop(no_a_c)

# %%
hotel.shape
# Out:
# (119210, 32)

# %% [markdown]
# Check adr column.The min number for adr is a negative number. The avergae daily rate should not be a negative number.

# %%
hotel.adr.describe()
# Out:
# count    119210.000000
# mean        101.969092
# std          50.434007
# min          -6.380000
# 25%          69.500000
# 50%          94.950000
# 75%         126.000000
# max        5400.000000
# Name: adr, dtype: float64

# %%
# There are 1811 orders that has a avergae daily rate of 0 or negative.
# The 0 adr could be some promotions, leave them there. 
hotel[hotel.adr<=0]
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 125     Resort Hotel            0         32               2015
# 167     Resort Hotel            0        111               2015
# 168     Resort Hotel            0          0               2015
# ...              ...          ...        ...                ...
# 118631    City Hotel            0         78               2017
# 118762    City Hotel            0          1               2017
# 118963    City Hotel            0          1               2017
# 119102    City Hotel            0        518               2017
# 119124    City Hotel            0          0               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# 125                  July                        27
# 167                  July                        28
# 168                  July                        28
# ...                   ...                       ...
# 118631             August                        34
# 118762             August                        34
# 118963             August                        35
# 119102             August                        34
# 119124             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 0                               1                        0
# 1                               1                        0
# 125                             4                        0
# 167                             6                        0
# 168                             6                        0
# ...                           ...                      ...
# 118631                         23                        0
# 118762                         24                        0
# 118963                         27                        0
# 119102                         26                        2
# 119124                         29                        0
#
#         stays_in_week_nights  adults  ...  deposit_type  agent company  \
# 0                          0       2  ...    No Deposit    NaN     NaN
# 1                          0       2  ...    No Deposit    NaN     NaN
# 125                        1       4  ...    No Deposit    NaN     NaN
# 167                        0       2  ...    No Deposit  240.0     NaN
# 168                        0       1  ...    No Deposit  250.0     NaN
# ...                      ...     ...  ...           ...    ...     ...
# 118631                     0       1  ...    No Deposit   98.0     NaN
# 118762                     1       2  ...    No Deposit    NaN     NaN
# 118963                     0       2  ...    No Deposit    NaN     NaN
# 119102                     1       1  ...    No Deposit  229.0     NaN
# 119124                     1       1  ...    No Deposit    NaN    72.0
#
#        days_in_waiting_list    customer_type  adr  \
# 0                         0        Transient  0.0
# 1                         0        Transient  0.0
# 125                       0        Transient  0.0
# 167                       0        Transient  0.0
# 168                       0        Transient  0.0
# ...                     ...              ...  ...
# 118631                    0  Transient-Party  0.0
# 118762                    0        Transient  0.0
# 118963                    0        Transient  0.0
# 119102                    0  Transient-Party  0.0
# 119124                    0        Transient  0.0
#
#         required_car_parking_spaces  total_of_special_requests  \
# 0                                 0                          0
# 1                                 0                          0
# 125                               0                          1
# 167                               0                          2
# 168                               0                          0
# ...                             ...                        ...
# 118631                            0                          0
# 118762                            0                          3
# 118963                            0                          0
# 119102                            0                          0
# 119124                            0                          2
#
#         reservation_status reservation_status_date
# 0                Check-Out              2015-07-01
# 1                Check-Out              2015-07-01
# 125              Check-Out              2015-07-05
# 167              Check-Out              2015-07-06
# 168              Check-Out              2015-07-06
# ...                    ...                     ...
# 118631           Check-Out              2017-08-23
# 118762           Check-Out              2017-08-25
# 118963           Check-Out              2017-08-27
# 119102           Check-Out              2017-08-29
# 119124           Check-Out              2017-08-30
#
# [1811 rows x 32 columns]

# %%
# There is one negative adr. This could be an error. Remove it.
hotel[hotel.adr<0]
# Out:
#               hotel  is_canceled  lead_time  arrival_date_year  \
# 14969  Resort Hotel            0        195               2017
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 14969              March                        10                          5
#
#        stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 14969                        4                     6       2  ...
#
#        deposit_type  agent company days_in_waiting_list    customer_type  \
# 14969    No Deposit  273.0     NaN                    0  Transient-Party
#
#         adr  required_car_parking_spaces  total_of_special_requests  \
# 14969 -6.38                            0                          0
#
#        reservation_status reservation_status_date
# 14969           Check-Out              2017-03-15
#
# [1 rows x 32 columns]

# %%
negative_adr = hotel[hotel.adr<0].index.tolist()
negative_adr
# Out:
# [14969]

# %%
hotel = hotel.drop(negative_adr)

# %%
hotel.shape
# Out:
# (119209, 32)

# %% [markdown]
# Check other columns, and see if there is something strange

# %%
hotel.is_repeated_guest.value_counts()
# Out:
# 0    115455
# 1      3754
# Name: is_repeated_guest, dtype: int64

# %%
hotel.deposit_type.value_counts()
# Out:
# No Deposit    104460
# Non Refund     14587
# Refundable       162
# Name: deposit_type, dtype: int64

# %%
hotel.market_segment.value_counts()
# Out:
# Online TA        56408
# Offline TA/TO    24182
# Groups           19790
# Direct           12582
# Corporate         5282
# Complementary      728
# Aviation           235
# Undefined            2
# Name: market_segment, dtype: int64

# %%
hotel.distribution_channel.value_counts()
# Out:
# TA/TO        97750
# Direct       14610
# Corporate     6651
# GDS            193
# Undefined        5
# Name: distribution_channel, dtype: int64

# %%
hotel.customer_type.value_counts()
# Out:
# Transient          89476
# Transient-Party    25087
# Contract            4072
# Group                574
# Name: customer_type, dtype: int64

# %%
hotel.reservation_status.value_counts()
# Out:
# Check-Out    75010
# Canceled     42993
# No-Show       1206
# Name: reservation_status, dtype: int64

# %% [markdown]
# Everything looks fine so far.

# %% [markdown]
# ### Missing Values

# %%
hotel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 119209 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119209 non-null  object
#  1   is_canceled                     119209 non-null  int64
#  2   lead_time                       119209 non-null  int64
#  3   arrival_date_year               119209 non-null  int64
#  4   arrival_date_month              119209 non-null  object
#  5   arrival_date_week_number        119209 non-null  int64
#  6   arrival_date_day_of_month       119209 non-null  int64
#  7   stays_in_weekend_nights         119209 non-null  int64
#  8   stays_in_week_nights            119209 non-null  int64
#  9   adults                          119209 non-null  int64
#  10  children                        119205 non-null  float64
#  11  babies                          119209 non-null  int64
#  12  meal                            119209 non-null  object
#  13  country                         118731 non-null  object
#  14  market_segment                  119209 non-null  object
#  15  distribution_channel            119209 non-null  object
#  16  is_repeated_guest               119209 non-null  int64
#  17  previous_cancellations          119209 non-null  int64
#  18  previous_bookings_not_canceled  119209 non-null  int64
#  19  reserved_room_type              119209 non-null  object
#  20  assigned_room_type              119209 non-null  object
#  21  booking_changes                 119209 non-null  int64
#  22  deposit_type                    119209 non-null  object
#  23  agent                           102929 non-null  float64
#  24  company                         6768 non-null    float64
#  25  days_in_waiting_list            119209 non-null  int64
#  26  customer_type                   119209 non-null  object
#  27  adr                             119209 non-null  float64
#  28  required_car_parking_spaces     119209 non-null  int64
#  29  total_of_special_requests       119209 non-null  int64
#  30  reservation_status              119209 non-null  object
#  31  reservation_status_date         119209 non-null  object
# dtypes: float64(4), int64(16), object(12)
# memory usage: 30.0+ MB

# %%
hotel.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              478
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# agent                              16280
# company                           112441
# days_in_waiting_list                   0
# customer_type                          0
# adr                                    0
# required_car_parking_spaces            0
# total_of_special_requests              0
# reservation_status                     0
# reservation_status_date                0
# dtype: int64

# %%
# check for NaNs in each column, there are 4 NaNs in children column and 488 Nas in country column
for i in range(hotel.shape[1]):
    print('NAs in ' + hotel.columns[i] + ' are ' + str(sum(hotel.iloc[:, i].isna())))
# Out:
# NAs in hotel are 0
# NAs in is_canceled are 0
# NAs in lead_time are 0
# NAs in arrival_date_year are 0
# NAs in arrival_date_month are 0
# NAs in arrival_date_week_number are 0
# NAs in arrival_date_day_of_month are 0
# NAs in stays_in_weekend_nights are 0
# NAs in stays_in_week_nights are 0
# NAs in adults are 0
# NAs in children are 4
# NAs in babies are 0
# NAs in meal are 0
# NAs in country are 478
# NAs in market_segment are 0
# NAs in distribution_channel are 0
# NAs in is_repeated_guest are 0
# NAs in previous_cancellations are 0
# NAs in previous_bookings_not_canceled are 0
# NAs in reserved_room_type are 0
# NAs in assigned_room_type are 0
# NAs in booking_changes are 0
# NAs in deposit_type are 0
# NAs in agent are 16280
# NAs in company are 112441
# NAs in days_in_waiting_list are 0
# NAs in customer_type are 0
# NAs in adr are 0
# NAs in required_car_parking_spaces are 0
# NAs in total_of_special_requests are 0
# NAs in reservation_status are 0
# NAs in reservation_status_date are 0

# %%
# There are lots of missing values in the agent and company columns 
# Based on the definition, missing values in agent and company column means that the customer did not order through an agent or a company
# fill the missing value with "No agent", 
hotel['agent'].fillna("No agent", inplace = True)
hotel['company'].fillna("No company", inplace = True)

# %%
hotel['children'].value_counts(dropna=False)
# Out:
# 0.0     110615
# 1.0       4861
# 2.0       3652
# 3.0         76
# NaN          4
# 10.0         1
# Name: children, dtype: int64

# %%
# The missing value for children column could be refuse to anwer. I will fill all NaNs with 0s
hotel['children'].fillna(0, inplace = True)

# %%
hotel['country'].value_counts(dropna=False)
# Out:
# PRT    48483
# GBR    12119
# FRA    10401
# ESP     8560
# DEU     7285
#        ...
# AIA        1
# CYM        1
# BFA        1
# MLI        1
# BDI        1
# Name: country, Length: 178, dtype: int64

# %%
# Dont use ffill, leave missing values in there

# %%
# The missing value for country column could be refuse to anwer. 
hotel['country'].fillna("No country", inplace = True)

# %%
# Check if the dataframe contains no missing values
hotel.notnull().all().all()
# Out:
# True

# %% [markdown]
# ### Data Type

# %%
hotel.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# deposit_type                       object
# agent                              object
# company                            object
# days_in_waiting_list                int64
# customer_type                      object
# adr                               float64
# required_car_parking_spaces         int64
# total_of_special_requests           int64
# reservation_status                 object
# reservation_status_date            object
# dtype: object

# %%
hotel['reservation_status_date'].head()
# Out:
# 0    2015-07-01
# 1    2015-07-01
# 2    2015-07-02
# 3    2015-07-02
# 4    2015-07-03
# Name: reservation_status_date, dtype: object

# %%
# number of children should be int
hotel['children'] = hotel['children'].astype('int64')
# The following columns should be categories
hotel['meal'] = hotel['meal'].astype('category')
hotel['country'] = hotel['country'].astype('category')
hotel['market_segment'] = hotel['market_segment'].astype('category')
hotel['reserved_room_type'] = hotel['reserved_room_type'].astype('category')
hotel['assigned_room_type'] = hotel['assigned_room_type'].astype('category')
hotel['deposit_type'] = hotel['deposit_type'].astype('category')
hotel['reservation_status'] = hotel['reservation_status'].astype('category')
hotel['distribution_channel']= hotel['distribution_channel'].astype('category')
hotel['customer_type'] = hotel['customer_type'].astype('category')

# %%
# reservation_status_date should be datetime
hotel['reservation_status_date_datetime'] = pd.to_datetime(hotel['reservation_status_date'])

# %%
hotel.dtypes
# Out:
# hotel                                       object
# is_canceled                                  int64
# lead_time                                    int64
# arrival_date_year                            int64
# arrival_date_month                          object
# arrival_date_week_number                     int64
# arrival_date_day_of_month                    int64
# stays_in_weekend_nights                      int64
# stays_in_week_nights                         int64
# adults                                       int64
# children                                     int64
# babies                                       int64
# meal                                      category
# country                                   category
# market_segment                            category
# distribution_channel                      category
# is_repeated_guest                            int64
# previous_cancellations                       int64
# previous_bookings_not_canceled               int64
# reserved_room_type                        category
# assigned_room_type                        category
# booking_changes                              int64
# deposit_type                              category
# agent                                       object
# company                                     object
# days_in_waiting_list                         int64
# customer_type                             category
# adr                                        float64
# required_car_parking_spaces                  int64
# total_of_special_requests                    int64
# reservation_status                        category
# reservation_status_date                     object
# reservation_status_date_datetime    datetime64[ns]
# dtype: object

# %%
# Check if transform the data type creates missing values
hotel.isnull().sum()
# Out:
# hotel                               0
# is_canceled                         0
# lead_time                           0
# arrival_date_year                   0
# arrival_date_month                  0
# arrival_date_week_number            0
# arrival_date_day_of_month           0
# stays_in_weekend_nights             0
# stays_in_week_nights                0
# adults                              0
# children                            0
# babies                              0
# meal                                0
# country                             0
# market_segment                      0
# distribution_channel                0
# is_repeated_guest                   0
# previous_cancellations              0
# previous_bookings_not_canceled      0
# reserved_room_type                  0
# assigned_room_type                  0
# booking_changes                     0
# deposit_type                        0
# agent                               0
# company                             0
# days_in_waiting_list                0
# customer_type                       0
# adr                                 0
# required_car_parking_spaces         0
# total_of_special_requests           0
# reservation_status                  0
# reservation_status_date             0
# reservation_status_date_datetime    0
# dtype: int64

# %%
#Check the data information again
hotel.describe().T
# Out:
#                                    count         mean         std     min  \
# is_canceled                     119209.0     0.370769    0.483013     0.0
# lead_time                       119209.0   104.108465  106.875574     0.0
# arrival_date_year               119209.0  2016.156465    0.707484  2015.0
# arrival_date_week_number        119209.0    27.163520   13.601073     1.0
# arrival_date_day_of_month       119209.0    15.798807    8.781051     1.0
# stays_in_weekend_nights         119209.0     0.927027    0.995081     0.0
# stays_in_week_nights            119209.0     2.499165    1.897087     0.0
# adults                          119209.0     1.859205    0.575188     0.0
# children                        119209.0     0.104044    0.398837     0.0
# babies                          119209.0     0.007961    0.097510     0.0
# is_repeated_guest               119209.0     0.031491    0.174641     0.0
# previous_cancellations          119209.0     0.087191    0.844922     0.0
# previous_bookings_not_canceled  119209.0     0.137079    1.498134     0.0
# booking_changes                 119209.0     0.218784    0.638486     0.0
# days_in_waiting_list            119209.0     2.321234   17.598074     0.0
# adr                             119209.0   101.970001   50.433242     0.0
# required_car_parking_spaces     119209.0     0.062554    0.245361     0.0
# total_of_special_requests       119209.0     0.571509    0.792877     0.0
#
#                                    25%      50%     75%     max
# is_canceled                        0.0     0.00     1.0     1.0
# lead_time                         18.0    69.00   161.0   737.0
# arrival_date_year               2016.0  2016.00  2017.0  2017.0
# arrival_date_week_number          16.0    28.00    38.0    53.0
# arrival_date_day_of_month          8.0    16.00    23.0    31.0
# stays_in_weekend_nights            0.0     1.00     2.0    19.0
# stays_in_week_nights               1.0     2.00     3.0    50.0
# adults                             2.0     2.00     2.0    55.0
# children                           0.0     0.00     0.0    10.0
# babies                             0.0     0.00     0.0    10.0
# is_repeated_guest                  0.0     0.00     0.0     1.0
# previous_cancellations             0.0     0.00     0.0    26.0
# previous_bookings_not_canceled     0.0     0.00     0.0    72.0
# booking_changes                    0.0     0.00     0.0    18.0
# days_in_waiting_list               0.0     0.00     0.0   391.0
# adr                               69.5    94.95   126.0  5400.0
# required_car_parking_spaces        0.0     0.00     0.0     8.0
# total_of_special_requests          0.0     0.00     1.0     5.0

# %%
hotel.describe(include=['object', 'category']).T
# Out:
#                           count unique         top    freq
# hotel                    119209      2  City Hotel   79163
# arrival_date_month       119209     12      August   13861
# meal                     119209      5          BB   92235
# country                  119209    178         PRT   48483
# market_segment           119209      8   Online TA   56408
# distribution_channel     119209      5       TA/TO   97750
# reserved_room_type       119209      9           A   85872
# assigned_room_type       119209     11           A   74020
# deposit_type             119209      3  No Deposit  104460
# agent                    119209    334           9   31922
# company                  119209    349  No company  112441
# customer_type            119209      4   Transient   89476
# reservation_status       119209      3   Check-Out   75010
# reservation_status_date  119209    926  2015-10-21    1460

# %% [markdown]
# ### Add new columns

# %%
look_up = {'January': 1, 'February': 2, 'March': 3, 'April': 4, 'May': 5, 'June': 6, 'July': 7, 'August': 8, 'September': 9, 'October': 10, 'November': 11, 'December': 12}
hotel['arrival_date_month_number'] = hotel['arrival_date_month'].apply(lambda x: look_up[x])

# %%
hotel['arrival_datetime'] = pd.to_datetime((hotel.arrival_date_year*10000+hotel.arrival_date_month_number*100+hotel.arrival_date_day_of_month).apply(str),format='%Y%m%d')

# %%
#hotel.drop(columns=['arrival_date_month_number'], inplace=True)

# %%
hotel.sample(5)
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 95999     City Hotel            0          3               2016
# 111882    City Hotel            0         13               2017
# 7502    Resort Hotel            1         92               2016
# 22090   Resort Hotel            0         10               2016
# 49879     City Hotel            0        270               2016
#
#        arrival_date_month  arrival_date_week_number  \
# 95999              August                        35
# 111882                May                        20
# 7502               August                        33
# 22090               March                        12
# 49879               April                        17
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 95999                          24                        0
# 111882                         14                        2
# 7502                           12                        2
# 22090                          17                        0
# 49879                          20                        0
#
#         stays_in_week_nights  adults  ...  days_in_waiting_list  \
# 95999                      3       2  ...                     0
# 111882                     1       2  ...                     0
# 7502                       2       2  ...                     0
# 22090                      1       1  ...                     0
# 49879                      4       2  ...                   187
#
#           customer_type     adr required_car_parking_spaces  \
# 95999         Transient  125.67                           0
# 111882        Transient  150.00                           0
# 7502          Transient  251.50                           0
# 22090   Transient-Party   30.00                           0
# 49879   Transient-Party   80.00                           0
#
#        total_of_special_requests reservation_status  reservation_status_date  \
# 95999                          1          Check-Out               2016-08-27
# 111882                         3          Check-Out               2017-05-17
# 7502                           0           Canceled               2016-05-16
# 22090                          1          Check-Out               2016-03-18
# 49879                          0          Check-Out               2016-04-24
#
#         reservation_status_date_datetime  arrival_date_month_number  \
# 95999                         2016-08-27                          8
# 111882                        2017-05-17                          5
# 7502                          2016-05-16                          8
# 22090                         2016-03-18                          3
# 49879                         2016-04-24                          4
#
#        arrival_datetime
# 95999        2016-08-24
# 111882       2017-05-14
# 7502         2016-08-12
# 22090        2016-03-17
# 49879        2016-04-20
#
# [5 rows x 35 columns]

# %%
hotel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 119209 entries, 0 to 119389
# Data columns (total 35 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   hotel                             119209 non-null  object
#  1   is_canceled                       119209 non-null  int64
#  2   lead_time                         119209 non-null  int64
#  3   arrival_date_year                 119209 non-null  int64
#  4   arrival_date_month                119209 non-null  object
#  5   arrival_date_week_number          119209 non-null  int64
#  6   arrival_date_day_of_month         119209 non-null  int64
#  7   stays_in_weekend_nights           119209 non-null  int64
#  8   stays_in_week_nights              119209 non-null  int64
#  9   adults                            119209 non-null  int64
#  10  children                          119209 non-null  int64
#  11  babies                            119209 non-null  int64
#  12  meal                              119209 non-null  category
#  13  country                           119209 non-null  category
#  14  market_segment                    119209 non-null  category
#  15  distribution_channel              119209 non-null  category
#  16  is_repeated_guest                 119209 non-null  int64
#  17  previous_cancellations            119209 non-null  int64
#  18  previous_bookings_not_canceled    119209 non-null  int64
#  19  reserved_room_type                119209 non-null  category
#  20  assigned_room_type                119209 non-null  category
#  21  booking_changes                   119209 non-null  int64
#  22  deposit_type                      119209 non-null  category
#  23  agent                             119209 non-null  object
#  24  company                           119209 non-null  object
#  25  days_in_waiting_list              119209 non-null  int64
#  26  customer_type                     119209 non-null  category
#  27  adr                               119209 non-null  float64
#  28  required_car_parking_spaces       119209 non-null  int64
#  29  total_of_special_requests         119209 non-null  int64
#  30  reservation_status                119209 non-null  category
#  31  reservation_status_date           119209 non-null  object
#  32  reservation_status_date_datetime  119209 non-null  datetime64[ns]
#  33  arrival_date_month_number         119209 non-null  int64
#  34  arrival_datetime                  119209 non-null  datetime64[ns]
# dtypes: category(9), datetime64[ns](2), float64(1), int64(18), object(5)
# memory usage: 25.7+ MB

# %% [markdown]
# ### Outliers

# %%
hotel.describe().T
# Out:
#                                    count         mean         std     min  \
# is_canceled                     119209.0     0.370769    0.483013     0.0
# lead_time                       119209.0   104.108465  106.875574     0.0
# arrival_date_year               119209.0  2016.156465    0.707484  2015.0
# arrival_date_week_number        119209.0    27.163520   13.601073     1.0
# arrival_date_day_of_month       119209.0    15.798807    8.781051     1.0
# stays_in_weekend_nights         119209.0     0.927027    0.995081     0.0
# stays_in_week_nights            119209.0     2.499165    1.897087     0.0
# adults                          119209.0     1.859205    0.575188     0.0
# children                        119209.0     0.104044    0.398837     0.0
# babies                          119209.0     0.007961    0.097510     0.0
# is_repeated_guest               119209.0     0.031491    0.174641     0.0
# previous_cancellations          119209.0     0.087191    0.844922     0.0
# previous_bookings_not_canceled  119209.0     0.137079    1.498134     0.0
# booking_changes                 119209.0     0.218784    0.638486     0.0
# days_in_waiting_list            119209.0     2.321234   17.598074     0.0
# adr                             119209.0   101.970001   50.433242     0.0
# required_car_parking_spaces     119209.0     0.062554    0.245361     0.0
# total_of_special_requests       119209.0     0.571509    0.792877     0.0
# arrival_date_month_number       119209.0     6.552081    3.089792     1.0
#
#                                    25%      50%     75%     max
# is_canceled                        0.0     0.00     1.0     1.0
# lead_time                         18.0    69.00   161.0   737.0
# arrival_date_year               2016.0  2016.00  2017.0  2017.0
# arrival_date_week_number          16.0    28.00    38.0    53.0
# arrival_date_day_of_month          8.0    16.00    23.0    31.0
# stays_in_weekend_nights            0.0     1.00     2.0    19.0
# stays_in_week_nights               1.0     2.00     3.0    50.0
# adults                             2.0     2.00     2.0    55.0
# children                           0.0     0.00     0.0    10.0
# babies                             0.0     0.00     0.0    10.0
# is_repeated_guest                  0.0     0.00     0.0     1.0
# previous_cancellations             0.0     0.00     0.0    26.0
# previous_bookings_not_canceled     0.0     0.00     0.0    72.0
# booking_changes                    0.0     0.00     0.0    18.0
# days_in_waiting_list               0.0     0.00     0.0   391.0
# adr                               69.5    94.95   126.0  5400.0
# required_car_parking_spaces        0.0     0.00     0.0     8.0
# total_of_special_requests          0.0     0.00     1.0     5.0
# arrival_date_month_number          4.0     7.00     9.0    12.0

# %%
all_hist = hotel.hist(bins=25,figsize=(15,14))

# %%
all_box = hotel.boxplot(vert=False,fontsize=13,figsize=(15,14))

# %%
#  Average Daily Rate as defined by dividing the sum of all lodging transactions by the total number of staying nights, 
#and it is left skewed, with an extremely large value
hotel.adr.hist(bins=25,figsize=(5,5))

# %%
hotel[hotel.adr==hotel.adr.max()]
# Out:
#             hotel  is_canceled  lead_time  arrival_date_year  \
# 48515  City Hotel            1         35               2016
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 48515              March                        13                         25
#
#        stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 48515                        0                     1       2  ...
#
#        days_in_waiting_list  customer_type     adr  \
# 48515                     0      Transient  5400.0
#
#       required_car_parking_spaces total_of_special_requests  \
# 48515                           0                         0
#
#       reservation_status  reservation_status_date  \
# 48515           Canceled               2016-02-19
#
#        reservation_status_date_datetime  arrival_date_month_number  \
# 48515                        2016-02-19                          3
#
#       arrival_datetime
# 48515       2016-03-25
#
# [1 rows x 35 columns]

# %%
hotel.assigned_room_type.value_counts()
# Out:
# A    74020
# D    25309
# E     7798
# F     3751
# G     2549
# C     2370
# B     2154
# H      711
# I      359
# K      187
# L        1
# Name: assigned_room_type, dtype: int64

# %%
# the assigned_room_type for this order is A, which is the most common room type. The price should not be significantly high. 
# This order is also been cancelled, this could mean that this order is cancelled because the price error.
# So I will drop this row
hotel.drop([48515], inplace=True)

# %%
# Check if droped
hotel.shape
# Out:
# (119208, 35)

# %%
hotel.adults.value_counts()
# Out:
# 2     89678
# 1     23027
# 3      6202
# 0       223
# 4        62
# 26        5
# 27        2
# 20        2
# 5         2
# 55        1
# 50        1
# 40        1
# 10        1
# 6         1
# Name: adults, dtype: int64

# %%
# This is a group order, could be a 55 people travel group. This makes sense. I will keep this row
hotel[hotel.adults==hotel.adults.max()]
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 2173  Resort Hotel            1        338               2015
#
#      arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 2173            October                        41                          4
#
#       stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 2173                        2                     0      55  ...
#
#       days_in_waiting_list  customer_type  adr required_car_parking_spaces  \
# 2173                     0          Group  0.0                           0
#
#      total_of_special_requests reservation_status  reservation_status_date  \
# 2173                         0           Canceled               2015-01-02
#
#       reservation_status_date_datetime  arrival_date_month_number  \
# 2173                        2015-01-02                         10
#
#      arrival_datetime
# 2173       2015-10-04
#
# [1 rows x 35 columns]

# %%
hotel.days_in_waiting_list.hist(bins=25,figsize=(5,5))

# %%
hotel.days_in_waiting_list.value_counts()
# Out:
# 0      115515
# 39        227
# 58        164
# 44        141
# 31        127
#         ...
# 37          1
# 109         1
# 52          1
# 72          1
# 74          1
# Name: days_in_waiting_list, Length: 127, dtype: int64

# %%
# There are lots of bookings stay in the wait list for a long while.
# By seeing the barplot is left skewed, these long waiting days are unusual, but valid information
# By considering that long waiting time could be a trigger to cancellation, these information should be kept
hotel[hotel.days_in_waiting_list==hotel.days_in_waiting_list.max()]
# Out:
#             hotel  is_canceled  lead_time  arrival_date_year  \
# 58152  City Hotel            1        443               2016
# 58153  City Hotel            1        443               2016
# 58154  City Hotel            1        443               2016
# 58155  City Hotel            1        443               2016
# 58157  City Hotel            1        443               2016
# 58158  City Hotel            1        443               2016
# 58159  City Hotel            1        443               2016
# 58160  City Hotel            1        443               2016
# 58161  City Hotel            1        443               2016
# 58167  City Hotel            1        443               2016
# 58171  City Hotel            1        443               2016
# 58172  City Hotel            1        443               2016
# 58176  City Hotel            1        443               2016
# 58177  City Hotel            1        443               2016
# 58179  City Hotel            1        443               2016
# 59076  City Hotel            1        457               2016
# 59077  City Hotel            1        457               2016
# 59084  City Hotel            1        457               2016
# 59085  City Hotel            1        457               2016
# 59090  City Hotel            1        457               2016
# 59091  City Hotel            1        457               2016
# 59095  City Hotel            1        457               2016
# 59096  City Hotel            1        457               2016
# 59105  City Hotel            1        457               2016
# 59109  City Hotel            1        457               2016
# 59110  City Hotel            1        457               2016
# 59113  City Hotel            1        457               2016
# 59120  City Hotel            1        457               2016
# 59123  City Hotel            1        457               2016
# 59142  City Hotel            1        457               2016
# 59395  City Hotel            1        464               2016
# 59397  City Hotel            1        464               2016
# 59403  City Hotel            1        464               2016
# 59407  City Hotel            1        464               2016
# 59408  City Hotel            1        464               2016
# 59411  City Hotel            1        464               2016
# 59412  City Hotel            1        464               2016
# 59421  City Hotel            1        464               2016
# 59430  City Hotel            1        464               2016
# 59431  City Hotel            1        464               2016
# 59434  City Hotel            1        464               2016
# 59435  City Hotel            1        464               2016
# 59444  City Hotel            1        464               2016
# 59450  City Hotel            1        464               2016
# 59454  City Hotel            1        464               2016
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 58152            October                        41                          7
# 58153            October                        41                          7
# 58154            October                        41                          7
# 58155            October                        41                          7
# 58157            October                        41                          7
# 58158            October                        41                          7
# 58159            October                        41                          7
# 58160            October                        41                          7
# 58161            October                        41                          7
# 58167            October                        41                          7
# 58171            October                        41                          7
# 58172            October                        41                          7
# 58176            October                        41                          7
# 58177            October                        41                          7
# 58179            October                        41                          7
# 59076            October                        43                         21
# 59077            October                        43                         21
# 59084            October                        43                         21
# 59085            October                        43                         21
# 59090            October                        43                         21
# 59091            October                        43                         21
# 59095            October                        43                         21
# 59096            October                        43                         21
# 59105            October                        43                         21
# 59109            October                        43                         21
# 59110            October                        43                         21
# 59113            October                        43                         21
# 59120            October                        43                         21
# 59123            October                        43                         21
# 59142            October                        43                         21
# 59395            October                        44                         28
# 59397            October                        44                         28
# 59403            October                        44                         28
# 59407            October                        44                         28
# 59408            October                        44                         28
# 59411            October                        44                         28
# 59412            October                        44                         28
# 59421            October                        44                         28
# 59430            October                        44                         28
# 59431            October                        44                         28
# 59434            October                        44                         28
# 59435            October                        44                         28
# 59444            October                        44                         28
# 59450            October                        44                         28
# 59454            October                        44                         28
#
#        stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 58152                        0                     2       2  ...
# 58153                        0                     2       2  ...
# 58154                        0                     2       2  ...
# 58155                        0                     2       2  ...
# 58157                        0                     2       2  ...
# 58158                        0                     2       2  ...
# 58159                        0                     2       2  ...
# 58160                        0                     2       2  ...
# 58161                        0                     2       2  ...
# 58167                        0                     2       2  ...
# 58171                        0                     2       2  ...
# 58172                        0                     2       2  ...
# 58176                        0                     2       2  ...
# 58177                        0                     2       2  ...
# 58179                        0                     2       2  ...
# 59076                        0                     2       2  ...
# 59077                        0                     2       2  ...
# 59084                        0                     2       2  ...
# 59085                        0                     2       2  ...
# 59090                        0                     2       2  ...
# 59091                        0                     2       2  ...
# 59095                        0                     2       2  ...
# 59096                        0                     2       2  ...
# 59105                        0                     2       2  ...
# 59109                        0                     2       2  ...
# 59110                        0                     2       2  ...
# 59113                        0                     2       2  ...
# 59120                        0                     2       2  ...
# 59123                        0                     2       2  ...
# 59142                        0                     2       2  ...
# 59395                        0                     2       2  ...
# 59397                        0                     2       2  ...
# 59403                        0                     2       2  ...
# 59407                        0                     2       2  ...
# 59408                        0                     2       2  ...
# 59411                        0                     2       2  ...
# 59412                        0                     2       2  ...
# 59421                        0                     2       2  ...
# 59430                        0                     2       2  ...
# 59431                        0                     2       2  ...
# 59434                        0                     2       2  ...
# 59435                        0                     2       2  ...
# 59444                        0                     2       2  ...
# 59450                        0                     2       2  ...
# 59454                        0                     2       2  ...
#
#        days_in_waiting_list  customer_type   adr required_car_parking_spaces  \
# 58152                   391      Transient  65.0                           0
# 58153                   391      Transient  65.0                           0
# 58154                   391      Transient  65.0                           0
# 58155                   391      Transient  65.0                           0
# 58157                   391      Transient  65.0                           0
# 58158                   391      Transient  65.0                           0
# 58159                   391      Transient  65.0                           0
# 58160                   391      Transient  65.0                           0
# 58161                   391      Transient  65.0                           0
# 58167                   391      Transient  65.0                           0
# 58171                   391      Transient  65.0                           0
# 58172                   391      Transient  65.0                           0
# 58176                   391      Transient  65.0                           0
# 58177                   391      Transient  65.0                           0
# 58179                   391      Transient  65.0                           0
# 59076                   391      Transient  65.0                           0
# 59077                   391      Transient  65.0                           0
# 59084                   391      Transient  65.0                           0
# 59085                   391      Transient  65.0                           0
# 59090                   391      Transient  65.0                           0
# 59091                   391      Transient  65.0                           0
# 59095                   391      Transient  65.0                           0
# 59096                   391      Transient  65.0                           0
# 59105                   391      Transient  65.0                           0
# 59109                   391      Transient  65.0                           0
# 59110                   391      Transient  65.0                           0
# 59113                   391      Transient  65.0                           0
# 59120                   391      Transient  65.0                           0
# 59123                   391      Transient  65.0                           0
# 59142                   391      Transient  65.0                           0
# 59395                   391      Transient  65.0                           0
# 59397                   391      Transient  65.0                           0
# 59403                   391      Transient  65.0                           0
# 59407                   391      Transient  65.0                           0
# 59408                   391      Transient  65.0                           0
# 59411                   391      Transient  65.0                           0
# 59412                   391      Transient  65.0                           0
# 59421                   391      Transient  65.0                           0
# 59430                   391      Transient  65.0                           0
# 59431                   391      Transient  65.0                           0
# 59434                   391      Transient  65.0                           0
# 59435                   391      Transient  65.0                           0
# 59444                   391      Transient  65.0                           0
# 59450                   391      Transient  65.0                           0
# 59454                   391      Transient  65.0                           0
#
#       total_of_special_requests reservation_status  reservation_status_date  \
# 58152                         0           Canceled               2016-09-20
# 58153                         0           Canceled               2016-09-20
# 58154                         0           Canceled               2016-09-20
# 58155                         0           Canceled               2016-09-20
# 58157                         0           Canceled               2016-09-20
# 58158                         0           Canceled               2016-09-20
# 58159                         0           Canceled               2016-09-20
# 58160                         0           Canceled               2016-09-20
# 58161                         0           Canceled               2016-09-20
# 58167                         0           Canceled               2016-09-20
# 58171                         0           Canceled               2016-09-20
# 58172                         0           Canceled               2016-09-20
# 58176                         0           Canceled               2016-09-20
# 58177                         0           Canceled               2016-09-20
# 58179                         0           Canceled               2016-09-20
# 59076                         0           Canceled               2016-09-20
# 59077                         0           Canceled               2016-09-20
# 59084                         0           Canceled               2016-09-20
# 59085                         0           Canceled               2016-09-20
# 59090                         0           Canceled               2016-09-20
# 59091                         0           Canceled               2016-09-20
# 59095                         0           Canceled               2016-09-20
# 59096                         0           Canceled               2016-09-20
# 59105                         0           Canceled               2016-09-20
# 59109                         0           Canceled               2016-09-20
# 59110                         0           Canceled               2016-09-20
# 59113                         0           Canceled               2016-09-20
# 59120                         0           Canceled               2016-09-20
# 59123                         0           Canceled               2016-09-20
# 59142                         0           Canceled               2016-09-20
# 59395                         0           Canceled               2016-09-20
# 59397                         0           Canceled               2016-09-20
# 59403                         0           Canceled               2016-09-20
# 59407                         0           Canceled               2016-09-20
# 59408                         0           Canceled               2016-09-20
# 59411                         0           Canceled               2016-09-20
# 59412                         0           Canceled               2016-09-20
# 59421                         0           Canceled               2016-09-20
# 59430                         0           Canceled               2016-09-20
# 59431                         0           Canceled               2016-09-20
# 59434                         0           Canceled               2016-09-20
# 59435                         0           Canceled               2016-09-20
# 59444                         0           Canceled               2016-09-20
# 59450                         0           Canceled               2016-09-20
# 59454                         0           Canceled               2016-09-20
#
#        reservation_status_date_datetime  arrival_date_month_number  \
# 58152                        2016-09-20                         10
# 58153                        2016-09-20                         10
# 58154                        2016-09-20                         10
# 58155                        2016-09-20                         10
# 58157                        2016-09-20                         10
# 58158                        2016-09-20                         10
# 58159                        2016-09-20                         10
# 58160                        2016-09-20                         10
# 58161                        2016-09-20                         10
# 58167                        2016-09-20                         10
# 58171                        2016-09-20                         10
# 58172                        2016-09-20                         10
# 58176                        2016-09-20                         10
# 58177                        2016-09-20                         10
# 58179                        2016-09-20                         10
# 59076                        2016-09-20                         10
# 59077                        2016-09-20                         10
# 59084                        2016-09-20                         10
# 59085                        2016-09-20                         10
# 59090                        2016-09-20                         10
# 59091                        2016-09-20                         10
# 59095                        2016-09-20                         10
# 59096                        2016-09-20                         10
# 59105                        2016-09-20                         10
# 59109                        2016-09-20                         10
# 59110                        2016-09-20                         10
# 59113                        2016-09-20                         10
# 59120                        2016-09-20                         10
# 59123                        2016-09-20                         10
# 59142                        2016-09-20                         10
# 59395                        2016-09-20                         10
# 59397                        2016-09-20                         10
# 59403                        2016-09-20                         10
# 59407                        2016-09-20                         10
# 59408                        2016-09-20                         10
# 59411                        2016-09-20                         10
# 59412                        2016-09-20                         10
# 59421                        2016-09-20                         10
# 59430                        2016-09-20                         10
# 59431                        2016-09-20                         10
# 59434                        2016-09-20                         10
# 59435                        2016-09-20                         10
# 59444                        2016-09-20                         10
# 59450                        2016-09-20                         10
# 59454                        2016-09-20                         10
#
#       arrival_datetime
# 58152       2016-10-07
# 58153       2016-10-07
# 58154       2016-10-07
# 58155       2016-10-07
# 58157       2016-10-07
# 58158       2016-10-07
# 58159       2016-10-07
# 58160       2016-10-07
# 58161       2016-10-07
# 58167       2016-10-07
# 58171       2016-10-07
# 58172       2016-10-07
# 58176       2016-10-07
# 58177       2016-10-07
# 58179       2016-10-07
# 59076       2016-10-21
# 59077       2016-10-21
# 59084       2016-10-21
# 59085       2016-10-21
# 59090       2016-10-21
# 59091       2016-10-21
# 59095       2016-10-21
# 59096       2016-10-21
# 59105       2016-10-21
# 59109       2016-10-21
# 59110       2016-10-21
# 59113       2016-10-21
# 59120       2016-10-21
# 59123       2016-10-21
# 59142       2016-10-21
# 59395       2016-10-28
# 59397       2016-10-28
# 59403       2016-10-28
# 59407       2016-10-28
# 59408       2016-10-28
# 59411       2016-10-28
# 59412       2016-10-28
# 59421       2016-10-28
# 59430       2016-10-28
# 59431       2016-10-28
# 59434       2016-10-28
# 59435       2016-10-28
# 59444       2016-10-28
# 59450       2016-10-28
# 59454       2016-10-28
#
# [45 rows x 35 columns]

# %%
hotel.previous_cancellations.hist(bins=25,figsize=(5,5))

# %%
# previous_cancellations is also a left skewed dataset. These information seems valid, so should not be dropped
hotel.previous_cancellations.value_counts()
# Out:
# 0     112729
# 1       6048
# 2        114
# 3         65
# 24        48
# 11        35
# 4         31
# 26        26
# 25        25
# 6         22
# 19        19
# 5         19
# 14        14
# 13        12
# 21         1
# Name: previous_cancellations, dtype: int64

# %%
# lead_time is also a left skewed dataset. These information seems valid, so should not be dropped
hotel.lead_time.hist(bins=25,figsize=(5,5))

# %% [markdown]
# ## Export data to a new csv file

# %% [markdown]
# Review the data before exporting

# %%
hotel.shape
# Out:
# (119208, 35)

# %%
hotel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 119208 entries, 0 to 119389
# Data columns (total 35 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   hotel                             119208 non-null  object
#  1   is_canceled                       119208 non-null  int64
#  2   lead_time                         119208 non-null  int64
#  3   arrival_date_year                 119208 non-null  int64
#  4   arrival_date_month                119208 non-null  object
#  5   arrival_date_week_number          119208 non-null  int64
#  6   arrival_date_day_of_month         119208 non-null  int64
#  7   stays_in_weekend_nights           119208 non-null  int64
#  8   stays_in_week_nights              119208 non-null  int64
#  9   adults                            119208 non-null  int64
#  10  children                          119208 non-null  int64
#  11  babies                            119208 non-null  int64
#  12  meal                              119208 non-null  category
#  13  country                           119208 non-null  category
#  14  market_segment                    119208 non-null  category
#  15  distribution_channel              119208 non-null  category
#  16  is_repeated_guest                 119208 non-null  int64
#  17  previous_cancellations            119208 non-null  int64
#  18  previous_bookings_not_canceled    119208 non-null  int64
#  19  reserved_room_type                119208 non-null  category
#  20  assigned_room_type                119208 non-null  category
#  21  booking_changes                   119208 non-null  int64
#  22  deposit_type                      119208 non-null  category
#  23  agent                             119208 non-null  object
#  24  company                           119208 non-null  object
#  25  days_in_waiting_list              119208 non-null  int64
#  26  customer_type                     119208 non-null  category
#  27  adr                               119208 non-null  float64
#  28  required_car_parking_spaces       119208 non-null  int64
#  29  total_of_special_requests         119208 non-null  int64
#  30  reservation_status                119208 non-null  category
#  31  reservation_status_date           119208 non-null  object
#  32  reservation_status_date_datetime  119208 non-null  datetime64[ns]
#  33  arrival_date_month_number         119208 non-null  int64
#  34  arrival_datetime                  119208 non-null  datetime64[ns]
# dtypes: category(9), datetime64[ns](2), float64(1), int64(18), object(5)
# memory usage: 25.7+ MB

# %%
hotel.describe().T
# Out:
#                                    count         mean         std     min  \
# is_canceled                     119208.0     0.370764    0.483011     0.0
# lead_time                       119208.0   104.109045  106.875835     0.0
# arrival_date_year               119208.0  2016.156466    0.707487  2015.0
# arrival_date_week_number        119208.0    27.163638   13.601068     1.0
# arrival_date_day_of_month       119208.0    15.798730    8.781048     1.0
# stays_in_weekend_nights         119208.0     0.927035    0.995082     0.0
# stays_in_week_nights            119208.0     2.499178    1.897090     0.0
# adults                          119208.0     1.859204    0.575190     0.0
# children                        119208.0     0.104045    0.398839     0.0
# babies                          119208.0     0.007961    0.097510     0.0
# is_repeated_guest               119208.0     0.031491    0.174642     0.0
# previous_cancellations          119208.0     0.087192    0.844925     0.0
# previous_bookings_not_canceled  119208.0     0.137080    1.498140     0.0
# booking_changes                 119208.0     0.218777    0.638485     0.0
# days_in_waiting_list            119208.0     2.321254   17.598147     0.0
# adr                             119208.0   101.925557   48.042334     0.0
# required_car_parking_spaces     119208.0     0.062555    0.245361     0.0
# total_of_special_requests       119208.0     0.571514    0.792879     0.0
# arrival_date_month_number       119208.0     6.552111    3.089788     1.0
#
#                                    25%      50%     75%     max
# is_canceled                        0.0     0.00     1.0     1.0
# lead_time                         18.0    69.00   161.0   737.0
# arrival_date_year               2016.0  2016.00  2017.0  2017.0
# arrival_date_week_number          16.0    28.00    38.0    53.0
# arrival_date_day_of_month          8.0    16.00    23.0    31.0
# stays_in_weekend_nights            0.0     1.00     2.0    19.0
# stays_in_week_nights               1.0     2.00     3.0    50.0
# adults                             2.0     2.00     2.0    55.0
# children                           0.0     0.00     0.0    10.0
# babies                             0.0     0.00     0.0    10.0
# is_repeated_guest                  0.0     0.00     0.0     1.0
# previous_cancellations             0.0     0.00     0.0    26.0
# previous_bookings_not_canceled     0.0     0.00     0.0    72.0
# booking_changes                    0.0     0.00     0.0    18.0
# days_in_waiting_list               0.0     0.00     0.0   391.0
# adr                               69.5    94.95   126.0   510.0
# required_car_parking_spaces        0.0     0.00     0.0     8.0
# total_of_special_requests          0.0     0.00     1.0     5.0
# arrival_date_month_number          4.0     7.00     9.0    12.0

# %% [markdown]
# Export data into "hotel_cleaned.csv"

# %%
# Create a file to store all data
#mkdir data

# %%
hotel.to_csv('D:\Jupyter_Notebook\Hotel_Cancellation\data\hotel_cleaned.csv',index=False, header=True)
